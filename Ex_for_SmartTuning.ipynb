# %%
# !git clone https://github.com/AustinHouston/pystemsim.git

# this gets you the cif file and pystemsim

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib ipympl

import secrets
from ase.io import read
from ase.visualize import view
import abtem
from abtem.atoms import orthogonalize_cell
import pyTEMlib.probe_tools as pt

sys.path.append('/Users/austin/Documents/GitHub/pystemsim/pystemsim')
import data_generator as dg
# Out:
# You don't have igor2 installed.     If you wish to open igor files, you will need to install it     (pip install igor2) before attempting.
# You don't have gwyfile installed.     If you wish to open .gwy files, you will need to      install it (pip install gwyfile) before attempting.
# Symmetry functions of spglib enabled

# %%
# Scattering potential
xtal = read('./crystal_files/WS2.cif')
xtal, transform = orthogonalize_cell(xtal, allow_transform=True, return_transform=True)
xtal = xtal * (30, 20, 1)
positions = xtal.get_positions()[:, :2]
pixel_size = 0.106 # angstrom/pixel
fov = 96 # angstroms
frame = (0,fov,0,fov) # limits of the image in angstroms
potential = dg.create_pseudo_potential(xtal, pixel_size, sigma=1, bounds=frame, atom_frame=11)

# Probe
ab = pt.get_target_aberrations("Spectra300", 60000)
ab['acceleration_voltage'] = 60e3 # eV
ab['FOV'] = fov /12 # Angstroms
ab['convergence_angle'] = 30 # mrad
ab['wavelength'] = pt.get_wavelength(ab['acceleration_voltage'])
ab['C10'] = 1
ab['C23a'] = 0
ab['C23b'] = 0
pt.print_aberrations(ab)
# Out:
# <html><body>Aberrations [nm] for acceleration voltage: 60 kV<table><tr><td> C10 </td><td> 1.0 </tr><tr><td> C12a (A1) </td><td>                  0.0 <td> C12b (A1) </td><td>                  0.4 </tr><tr><td> C21a (B2) </td><td> -68.5 <td> C21b (B2)</td><td> 64.9     <td> C23a (A2) </td><td> 0.0 <td> C23b (A2) </td><td> 0.0 </tr><tr><td> C30 </td><td> 123.0 </tr><tr><td> C32a (S3) </td><td>                 95.3 <td> C32b (S3)</td><td>               -189.7 <td> C34a (A3) </td><td>                -47.5 <td> C34b (A3) </td><td>                -94.7 </tr><tr><td> C41a (B4) </td><td> -905 <td> C41b (B4) </td><td> 981     <td> C43a (D4) </td><td> 4.02e+03 <td> C43b (D4) </td><td> 981     <td> C45a (A4) </td><td> -4.7e+03 <td> C45b (A4)</td><td> -208 </tr><tr><td> C50 </td><td> 5.52e+05 </tr><tr><td> C52a </td><td>                 -0.0 <td> C52b </td><td>                  0.0 <td> C54a </td><td>                 -0.0 <td> C54b </td><td>                 -0.0 <td> C56a </td><td>             -36663.6 <td> C56b </td><td>              21356.1 </tr><tr><td> Cc </td><td> 1e+06 </tr></table></body></html>

# %%
plt.figure()
plt.imshow(potential.T)

# %%
# change ab here
ab['C10'] = -1 # defocus
ab['C12a'] = 0 # twofold astigmatism (a)
ab['C12b'] = 0 # twofold astigmatism (b)
ab['C23a'] = 0 # threefold astigmatism (a)
ab['C21a'] = 0 # axial coma (a)
probe = dg.get_probe(ab, potential)
image = dg.convolve_kernel(potential, probe)
noisy_image = dg.lowfreq_noise(image, noise_level=0.5, freq_scale=.04)
sim_im = dg.poisson_noise(noisy_image, counts=1e7)

view = sim_im.plot()
# Out:
# 0.03
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.imshow(probe.T)
plt.colorbar()

# %%
def contrast_rms(im):
    return np.std(im) / np.mean(im)

# next, we should try other metrics, maybe based on ronchigram - will require more expensive calculations

# %% [markdown]
# ### Defocus

# %%
param_range = 8
params = np.linspace(-param_range, param_range, 21)

rms_contrasts = []
images = []
for defocus in params:
    ab['C10'] = defocus
    probe = dg.get_probe(ab, potential)
    image = dg.convolve_kernel(potential, probe)
    noisy_image = dg.lowfreq_noise(image, noise_level=0.5, freq_scale=.04)
    sim_im = dg.poisson_noise(noisy_image, counts=1e7)
    rms_contrasts.append(contrast_rms(np.array(sim_im)))
    images.append(sim_im)
ab['C10'] = 0
plt.figure()
plt.plot(params, rms_contrasts)
# Out:
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### 2-fold Astigmatism a (b is same)

# %%
param_range = 10
params = np.linspace(-param_range, param_range, 21)

rms_contrasts = []
images = []
for defocus in params:
    ab['C12a'] = defocus
    probe = dg.get_probe(ab, potential)
    image = dg.convolve_kernel(potential, probe)
    noisy_image = dg.lowfreq_noise(image, noise_level=0.5, freq_scale=.04)
    sim_im = dg.poisson_noise(noisy_image, counts=1e7)
    rms_contrasts.append(contrast_rms(np.array(sim_im)))
    images.append(sim_im)
ab['C12a'] = 0
plt.figure()
plt.plot(params, rms_contrasts)
# Out:
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### 3-fold Astigmatism a (b is same)

# %%
param_range = 200
params = np.linspace(-param_range, param_range, 21)

rms_contrasts = []
images = []
for defocus in params:
    ab['C23a'] = defocus
    probe = dg.get_probe(ab, potential)
    image = dg.convolve_kernel(potential, probe)
    noisy_image = dg.lowfreq_noise(image, noise_level=0.5, freq_scale=.04)
    sim_im = dg.poisson_noise(noisy_image, counts=1e7)
    rms_contrasts.append(contrast_rms(np.array(sim_im)))
    images.append(sim_im)
ab['C23a'] = 0
plt.figure()
plt.plot(params, rms_contrasts)
# Out:
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Coma (B2a) (B2B is same)

# %%
param_range = 500
params = np.linspace(-param_range, param_range, 21)

rms_contrasts = []
images = []
for defocus in params:
    ab['C21a'] = defocus
    probe = dg.get_probe(ab, potential)
    image = dg.convolve_kernel(potential, probe)
    noisy_image = dg.lowfreq_noise(image, noise_level=0.5, freq_scale=.04)
    sim_im = dg.poisson_noise(noisy_image, counts=1e7)
    rms_contrasts.append(contrast_rms(np.array(sim_im)))
    images.append(sim_im)
ab['C21a'] = 0
plt.figure()
plt.plot(params, rms_contrasts)
# Out:
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
